# %%
# Install FUSION++
# !pip install "git+https://github.com/SarderLab/fusion-packages.git"
# Run this command only if you are not working in the FUSION environment

# %%
# Import FUSION++
import fusion
# After installation, a demo notebook will be downloaded into your workapace. PATH: fusion_demo_notebooks/fusion_demo.ipynb
